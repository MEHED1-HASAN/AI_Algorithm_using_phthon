# %%
import tensorflow as tf
from tensorflow.keras import layers,models

(x_train,y_train),(x_test,y_test)=tf.keras.datasets.cifar10.load_data()
x_train=x_train.astype('float32')/255.0
x_test=x_test.astype('float32')/255.0
y_train=y_train.flatten()
y_test=y_test.flatten()

model=models.Sequential([
    layers.Input(shape=(32,32,3)),
    layers.Conv2D(32,(3,3),activation='relu',padding='same'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,(3,3),activation='relu',padding='same'),
    layers.MaxPooling2D(),
    layers.Conv2D(128,(3,3),activation='relu',padding='same'),
    layers.GlobalAveragePooling2D(),
    layers.Dense(128,activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10,activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

model.fit(x_train,y_train,epochs=25,batch_size=64,validation_split=0.1)

loss,acc=model.evaluate(x_test,y_test,verbose=2)
print(f"Test loss={loss:.4f}, acc={acc:.4f}")

model.save('cnn_cifar10.h5')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 405s 2us/step
# Epoch 1/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.2806 - loss: 1.8744 - val_accuracy: 0.4044 - val_loss: 1.6045
# Epoch 2/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.4275 - loss: 1.5449 - val_accuracy: 0.4740 - val_loss: 1.4269
# Epoch 3/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.4958 - loss: 1.3775 - val_accuracy: 0.5618 - val_loss: 1.2283
# Epoch 4/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.5354 - loss: 1.2737 - val_accuracy: 0.5796 - val_loss: 1.1756
# Epoch 5/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.5657 - loss: 1.1958 - val_accuracy: 0.5926 - val_loss: 1.1197
# Epoch 6/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.5936 - loss: 1.1263 - val_accuracy: 0.6288 - val_loss: 1.0384
# Epoch 7/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.6133 - loss: 1.0810 - val_accuracy: 0.6370 - val_loss: 1.0098
# Epoch 8/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.6312 - loss: 1.0309 - val_accuracy: 0.6374 - val_loss: 1.0007
# Epoch 9/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.6481 - loss: 0.9863 - val_accuracy: 0.6596 - val_loss: 0.9429
# Epoch 10/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.6590 - loss: 0.9593 - val_accuracy: 0.6726 - val_loss: 0.9227
# Epoch 11/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 27s 38ms/step - accuracy: 0.6779 - loss: 0.9106 - val_accuracy: 0.6870 - val_loss: 0.8731
# Epoch 12/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 26s 37ms/step - accuracy: 0.6872 - loss: 0.8839 - val_accuracy: 0.6936 - val_loss: 0.8787
# Epoch 13/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.7002 - loss: 0.8498 - val_accuracy: 0.6978 - val_loss: 0.8461
# Epoch 14/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.7106 - loss: 0.8206 - val_accuracy: 0.7216 - val_loss: 0.7991
# Epoch 15/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - accuracy: 0.7213 - loss: 0.7894 - val_accuracy: 0.7224 - val_loss: 0.8015
# Epoch 16/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7267 - loss: 0.7715 - val_accuracy: 0.7316 - val_loss: 0.7682
# Epoch 17/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.7365 - loss: 0.7457 - val_accuracy: 0.7216 - val_loss: 0.8088
# Epoch 18/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7447 - loss: 0.7262 - val_accuracy: 0.7042 - val_loss: 0.8362
# Epoch 19/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.7542 - loss: 0.6995 - val_accuracy: 0.7486 - val_loss: 0.7199
# Epoch 20/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 22s 32ms/step - accuracy: 0.7618 - loss: 0.6790 - val_accuracy: 0.7462 - val_loss: 0.7200
# Epoch 21/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.7667 - loss: 0.6660 - val_accuracy: 0.7400 - val_loss: 0.7499
# Epoch 22/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.7742 - loss: 0.6477 - val_accuracy: 0.7550 - val_loss: 0.7066
# Epoch 23/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.7766 - loss: 0.6331 - val_accuracy: 0.7470 - val_loss: 0.7184
# Epoch 24/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7829 - loss: 0.6177 - val_accuracy: 0.7524 - val_loss: 0.7147
# Epoch 25/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7881 - loss: 0.5963 - val_accuracy: 0.7648 - val_loss: 0.6754
# 313/313 - 2s - 6ms/step - accuracy: 0.7534 - loss: 0.7038
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test loss=0.7038, acc=0.7534
