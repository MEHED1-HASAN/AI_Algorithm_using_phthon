# %%
import tensorflow as tf
from tensorflow.keras import layers,models

(x_train,y_train),(x_test,y_test)=tf.keras.datasets.cifar10.load_data()
x_train=x_train.astype('float32')/255.0
x_test=x_test.astype('float32')/255.0
y_train=y_train.flatten()
y_test=y_test.flatten()

model=models.Sequential([
    layers.Input(shape=(32,32,3)),
    layers.Conv2D(32,(3,3),activation='relu',padding='same'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,(3,3),activation='relu',padding='same'),
    layers.MaxPooling2D(),
    layers.Conv2D(128,(3,3),activation='relu',padding='same'),
    layers.GlobalAveragePooling2D(),
    layers.Dense(128,activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10,activation='softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

model.fit(x_train,y_train,epochs=25,batch_size=64,validation_split=0.1)

loss,acc=model.evaluate(x_test,y_test,verbose=2)
print(f"Test loss={loss:.4f}, acc={acc:.4f}")

model.save('cnn_cifar10.h5')
# Out:
# Epoch 1/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.2941 - loss: 1.8521 - val_accuracy: 0.3602 - val_loss: 1.7210
# Epoch 2/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.4162 - loss: 1.5643 - val_accuracy: 0.4774 - val_loss: 1.4219
# Epoch 3/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.4844 - loss: 1.4034 - val_accuracy: 0.5284 - val_loss: 1.2888
# Epoch 4/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.5303 - loss: 1.2929 - val_accuracy: 0.5510 - val_loss: 1.2578
# Epoch 5/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.5611 - loss: 1.2125 - val_accuracy: 0.5634 - val_loss: 1.2162
# Epoch 6/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.5892 - loss: 1.1499 - val_accuracy: 0.5918 - val_loss: 1.1118
# Epoch 7/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.6072 - loss: 1.0962 - val_accuracy: 0.5922 - val_loss: 1.1547
# Epoch 8/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 28ms/step - accuracy: 0.6264 - loss: 1.0503 - val_accuracy: 0.6654 - val_loss: 0.9458
# Epoch 9/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.6444 - loss: 1.0033 - val_accuracy: 0.6512 - val_loss: 0.9744
# Epoch 10/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 28ms/step - accuracy: 0.6549 - loss: 0.9712 - val_accuracy: 0.6816 - val_loss: 0.9193
# Epoch 11/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 28ms/step - accuracy: 0.6673 - loss: 0.9330 - val_accuracy: 0.7002 - val_loss: 0.8606
# Epoch 12/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 28ms/step - accuracy: 0.6786 - loss: 0.8993 - val_accuracy: 0.6930 - val_loss: 0.8761
# Epoch 13/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.6867 - loss: 0.8795 - val_accuracy: 0.6672 - val_loss: 0.9317
# Epoch 14/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 28ms/step - accuracy: 0.7007 - loss: 0.8472 - val_accuracy: 0.6948 - val_loss: 0.8531
# Epoch 15/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7090 - loss: 0.8212 - val_accuracy: 0.7242 - val_loss: 0.8009
# Epoch 16/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7182 - loss: 0.7986 - val_accuracy: 0.7154 - val_loss: 0.7958
# Epoch 17/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7282 - loss: 0.7694 - val_accuracy: 0.7184 - val_loss: 0.7956
# Epoch 18/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7364 - loss: 0.7511 - val_accuracy: 0.7314 - val_loss: 0.7560
# Epoch 19/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7400 - loss: 0.7328 - val_accuracy: 0.7366 - val_loss: 0.7664
# Epoch 20/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.7509 - loss: 0.7060 - val_accuracy: 0.7428 - val_loss: 0.7426
# Epoch 21/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.7561 - loss: 0.6925 - val_accuracy: 0.7318 - val_loss: 0.7667
# Epoch 22/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.7654 - loss: 0.6697 - val_accuracy: 0.7420 - val_loss: 0.7425
# Epoch 23/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7706 - loss: 0.6508 - val_accuracy: 0.7370 - val_loss: 0.7584
# Epoch 24/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7779 - loss: 0.6360 - val_accuracy: 0.7544 - val_loss: 0.7061
# Epoch 25/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7855 - loss: 0.6159 - val_accuracy: 0.7610 - val_loss: 0.6981
# 313/313 - 2s - 6ms/step - accuracy: 0.7540 - loss: 0.7139
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test loss=0.7139, acc=0.7540

# %%
import tensorflow as tf
from tensorflow.keras import layers,models
import matplotlib.pyplot as plt

(x_train,y_train),(x_test,y_test)=tf.keras.datasets.cifar10.load_data()
x_train=x_train.astype('float32')/255.0
x_test=x_test.astype('float32')/255.0
y_train=y_train.flatten()
y_test=y_test.flatten()

model=models.Sequential([
    layers.Input(shape=(32,32,3)),
    layers.Conv2D(32,(3,3),activation='relu',padding='same'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,(3,3),activation='relu',padding='same'),
    layers.MaxPooling2D(),
    layers.Conv2D(128,(3,3),activation='relu',padding='same'),
    layers.GlobalAveragePooling2D(),
    layers.Dense(128,activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10,activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history=model.fit(x_train,y_train,epochs=25,batch_size=64,validation_split=0.1)

loss,acc=model.evaluate(x_test,y_test,verbose=2)
print(f"Test loss={loss:.4f}, acc={acc:.4f}")

plt.plot(history.history['accuracy'],label='Train Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - accuracy: 0.2892 - loss: 1.8529 - val_accuracy: 0.3974 - val_loss: 1.5972
# Epoch 2/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.4319 - loss: 1.5267 - val_accuracy: 0.4902 - val_loss: 1.3819
# Epoch 3/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.4960 - loss: 1.3776 - val_accuracy: 0.5132 - val_loss: 1.3241
# Epoch 4/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.5310 - loss: 1.2875 - val_accuracy: 0.5370 - val_loss: 1.2811
# Epoch 5/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.5585 - loss: 1.2207 - val_accuracy: 0.6008 - val_loss: 1.0961
# Epoch 6/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.5824 - loss: 1.1562 - val_accuracy: 0.5982 - val_loss: 1.0861
# Epoch 7/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.6028 - loss: 1.1075 - val_accuracy: 0.6172 - val_loss: 1.0393
# Epoch 8/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.6195 - loss: 1.0611 - val_accuracy: 0.6454 - val_loss: 0.9886
# Epoch 9/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 27ms/step - accuracy: 0.6351 - loss: 1.0211 - val_accuracy: 0.6612 - val_loss: 0.9655
# Epoch 10/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.6489 - loss: 0.9864 - val_accuracy: 0.6504 - val_loss: 0.9670
# Epoch 11/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.6635 - loss: 0.9490 - val_accuracy: 0.6866 - val_loss: 0.8830
# Epoch 12/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.6752 - loss: 0.9141 - val_accuracy: 0.6762 - val_loss: 0.9133
# Epoch 13/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.6858 - loss: 0.8860 - val_accuracy: 0.6998 - val_loss: 0.8398
# Epoch 14/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.6974 - loss: 0.8569 - val_accuracy: 0.6888 - val_loss: 0.8883
# Epoch 15/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7073 - loss: 0.8285 - val_accuracy: 0.7046 - val_loss: 0.8367
# Epoch 16/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7195 - loss: 0.7982 - val_accuracy: 0.7272 - val_loss: 0.7957
# Epoch 17/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7260 - loss: 0.7763 - val_accuracy: 0.7302 - val_loss: 0.7889
# Epoch 18/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7336 - loss: 0.7572 - val_accuracy: 0.7328 - val_loss: 0.7788
# Epoch 19/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7418 - loss: 0.7360 - val_accuracy: 0.7366 - val_loss: 0.7692
# Epoch 20/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 28ms/step - accuracy: 0.7485 - loss: 0.7179 - val_accuracy: 0.7330 - val_loss: 0.7667
# Epoch 21/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 28ms/step - accuracy: 0.7570 - loss: 0.6969 - val_accuracy: 0.7410 - val_loss: 0.7458
# Epoch 22/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 28ms/step - accuracy: 0.7639 - loss: 0.6726 - val_accuracy: 0.7482 - val_loss: 0.7273
# Epoch 23/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 19s 28ms/step - accuracy: 0.7732 - loss: 0.6546 - val_accuracy: 0.7536 - val_loss: 0.7011
# Epoch 24/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 28ms/step - accuracy: 0.7758 - loss: 0.6374 - val_accuracy: 0.7578 - val_loss: 0.7168
# Epoch 25/25
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.7809 - loss: 0.6267 - val_accuracy: 0.7446 - val_loss: 0.7796
# 313/313 - 2s - 6ms/step - accuracy: 0.7340 - loss: 0.7776
# Test loss=0.7776, acc=0.7340
