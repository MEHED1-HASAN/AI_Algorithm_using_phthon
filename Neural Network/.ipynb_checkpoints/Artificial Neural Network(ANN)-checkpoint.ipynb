# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score,classification_report

df=pd.read_csv('iris.csv')
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

label_encoder=LabelEncoder()
y_encoded=label_encoder.fit_transform(y)
y_categorical=to_categorical(y_encoded)

X_train,X_test,y_train,y_test=train_test_split(X,y_categorical,test_size=0.2,random_state=42)

scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

model=Sequential()
model.add(Dense(64,input_dim=X_train.shape[1],activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(3,activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

history=model.fit(X_train,y_train,epochs=50,batch_size=10,validation_split=0.1,verbose=1)

y_pred=model.predict(X_test)
y_pred_classes=np.argmax(y_pred,axis=1)
y_test_classes=np.argmax(y_test,axis=1)
accuracy=accuracy_score(y_test_classes,y_pred_classes)

print(f"Test Accuracy: {accuracy*100:.2f}%")
print(classification_report(y_test_classes,y_pred_classes,target_names=label_encoder.classes_))


sample=X_test[[0]]
pred=model.predict(sample)
cls=np.argmax(pred, axis=1)
print("Predicted:",label_encoder.inverse_transform(cls)[0])

plt.plot(history.history['accuracy'],label='train accuracy',color='blue')
plt.plot(history.history['val_accuracy'],label='validation accuracy',color='green')
plt.title('model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
# Out:
# Epoch 1/50
# c:\Users\Mehedi Hasan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.4722 - loss: 0.9801 - val_accuracy: 0.5000 - val_loss: 0.9471
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7778 - loss: 0.7787 - val_accuracy: 0.5000 - val_loss: 0.8425
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8241 - loss: 0.6367 - val_accuracy: 0.5000 - val_loss: 0.7526
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8241 - loss: 0.5262 - val_accuracy: 0.6667 - val_loss: 0.6747
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8426 - loss: 0.4438 - val_accuracy: 0.7500 - val_loss: 0.6102
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8611 - loss: 0.3822 - val_accuracy: 0.8333 - val_loss: 0.5572
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9074 - loss: 0.3320 - val_accuracy: 0.8333 - val_loss: 0.5141
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9167 - loss: 0.2920 - val_accuracy: 0.9167 - val_loss: 0.4786
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9259 - loss: 0.2566 - val_accuracy: 0.9167 - val_loss: 0.4512
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9352 - loss: 0.2288 - val_accuracy: 0.9167 - val_loss: 0.4241
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9537 - loss: 0.2034 - val_accuracy: 0.9167 - val_loss: 0.3959
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9537 - loss: 0.1796 - val_accuracy: 0.9167 - val_loss: 0.3835
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9630 - loss: 0.1591 - val_accuracy: 0.9167 - val_loss: 0.3661
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9630 - loss: 0.1406 - val_accuracy: 0.9167 - val_loss: 0.3499
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.1249 - val_accuracy: 0.9167 - val_loss: 0.3362
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9815 - loss: 0.1111 - val_accuracy: 0.9167 - val_loss: 0.3260
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9907 - loss: 0.0996 - val_accuracy: 0.9167 - val_loss: 0.3194
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9907 - loss: 0.0900 - val_accuracy: 0.9167 - val_loss: 0.3055
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9907 - loss: 0.0807 - val_accuracy: 0.9167 - val_loss: 0.3078
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9907 - loss: 0.0718 - val_accuracy: 0.9167 - val_loss: 0.2893
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0628 - val_accuracy: 0.9167 - val_loss: 0.2873
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0565 - val_accuracy: 0.9167 - val_loss: 0.2921
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0508 - val_accuracy: 0.9167 - val_loss: 0.2820
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0458 - val_accuracy: 0.9167 - val_loss: 0.2702
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0410 - val_accuracy: 0.9167 - val_loss: 0.2705
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0374 - val_accuracy: 0.9167 - val_loss: 0.2735
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0339 - val_accuracy: 0.9167 - val_loss: 0.2696
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0321 - val_accuracy: 0.9167 - val_loss: 0.2542
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 0.9167 - val_loss: 0.2638
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0257 - val_accuracy: 0.9167 - val_loss: 0.2513
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0235 - val_accuracy: 0.9167 - val_loss: 0.2510
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0215 - val_accuracy: 0.9167 - val_loss: 0.2503
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0201 - val_accuracy: 0.9167 - val_loss: 0.2518
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0184 - val_accuracy: 0.9167 - val_loss: 0.2445
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0168 - val_accuracy: 0.9167 - val_loss: 0.2401
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0158 - val_accuracy: 0.9167 - val_loss: 0.2472
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.9167 - val_loss: 0.2428
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.9167 - val_loss: 0.2325
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.9167 - val_loss: 0.2358
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.9167 - val_loss: 0.2371
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.9167 - val_loss: 0.2407
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.9167 - val_loss: 0.2422
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.9167 - val_loss: 0.2325
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.9167 - val_loss: 0.2332
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9167 - val_loss: 0.2285
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9167 - val_loss: 0.2335
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.9167 - val_loss: 0.2387
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.9167 - val_loss: 0.2318
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9167 - val_loss: 0.2283
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9167 - val_loss: 0.2226
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Test Accuracy: 100.00%
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00         9
#  Iris-virginica       1.00      1.00      1.00        11
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Predicted: Iris-versicolor

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score, classification_report

iris=load_iris()
X=iris.data
y=iris.target
target_names=iris.target_names

y_categorical=to_categorical(y)

X_train,X_test,y_train,y_test=train_test_split(X,y_categorical,test_size=0.2,random_state=42)

scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

model=Sequential()
model.add(Dense(64,input_dim=X_train.shape[1],activation='relu'))
model.add(Dense(32,activation='relu'))
model.add(Dense(3,activation='softmax'))

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

history=model.fit(X_train,y_train,epochs=50,batch_size=10,validation_split=0.1,verbose=1)

y_pred=model.predict(X_test)
y_pred_classes=np.argmax(y_pred,axis=1)
y_test_classes=np.argmax(y_test,axis=1)
accuracy=accuracy_score(y_test_classes,y_pred_classes)

print(f"Test Accuracy: {accuracy*100:.2f}%")
print(classification_report(y_test_classes,y_pred_classes,target_names=target_names))

sample=X_test[[0]]
pred=model.predict(sample)
cls=np.argmax(pred,axis=1)
print("Predicted:",target_names[cls[0]])

plt.plot(history.history['accuracy'],label='train accuracy',color='blue')
plt.plot(history.history['val_accuracy'],label='validation accuracy',color='green')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\Mehedi Hasan\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.4815 - loss: 1.0367 - val_accuracy: 0.5833 - val_loss: 0.9833
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7963 - loss: 0.8238 - val_accuracy: 0.6667 - val_loss: 0.8548
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7963 - loss: 0.6785 - val_accuracy: 0.6667 - val_loss: 0.7637
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8056 - loss: 0.5681 - val_accuracy: 0.6667 - val_loss: 0.6889
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8056 - loss: 0.4946 - val_accuracy: 0.7500 - val_loss: 0.6322
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8241 - loss: 0.4397 - val_accuracy: 0.7500 - val_loss: 0.5862
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8148 - loss: 0.4048 - val_accuracy: 0.8333 - val_loss: 0.5510
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8148 - loss: 0.3730 - val_accuracy: 0.8333 - val_loss: 0.5148
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8241 - loss: 0.3493 - val_accuracy: 0.8333 - val_loss: 0.4874
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8333 - loss: 0.3295 - val_accuracy: 0.9167 - val_loss: 0.4661
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8426 - loss: 0.3097 - val_accuracy: 0.9167 - val_loss: 0.4463
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8611 - loss: 0.2928 - val_accuracy: 0.9167 - val_loss: 0.4252
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8796 - loss: 0.2768 - val_accuracy: 0.9167 - val_loss: 0.3992
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8889 - loss: 0.2610 - val_accuracy: 0.9167 - val_loss: 0.3859
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8889 - loss: 0.2476 - val_accuracy: 0.9167 - val_loss: 0.3578
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9074 - loss: 0.2303 - val_accuracy: 0.9167 - val_loss: 0.3492
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9630 - loss: 0.2193 - val_accuracy: 0.9167 - val_loss: 0.3501
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9537 - loss: 0.2019 - val_accuracy: 0.9167 - val_loss: 0.3205
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9630 - loss: 0.1898 - val_accuracy: 0.9167 - val_loss: 0.3208
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9444 - loss: 0.1792 - val_accuracy: 0.9167 - val_loss: 0.2963
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9444 - loss: 0.1692 - val_accuracy: 0.9167 - val_loss: 0.3150
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9537 - loss: 0.1584 - val_accuracy: 0.9167 - val_loss: 0.2899
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9537 - loss: 0.1430 - val_accuracy: 0.9167 - val_loss: 0.3018
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9630 - loss: 0.1349 - val_accuracy: 0.9167 - val_loss: 0.3018
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9630 - loss: 0.1263 - val_accuracy: 0.9167 - val_loss: 0.2953
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9537 - loss: 0.1240 - val_accuracy: 0.9167 - val_loss: 0.2786
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9537 - loss: 0.1161 - val_accuracy: 0.9167 - val_loss: 0.3146
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.1090 - val_accuracy: 0.9167 - val_loss: 0.3120
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9537 - loss: 0.1133 - val_accuracy: 0.9167 - val_loss: 0.2603
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9630 - loss: 0.0984 - val_accuracy: 0.9167 - val_loss: 0.3138
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9815 - loss: 0.0961 - val_accuracy: 0.9167 - val_loss: 0.3115
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9722 - loss: 0.0896 - val_accuracy: 0.9167 - val_loss: 0.3071
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9722 - loss: 0.0883 - val_accuracy: 0.9167 - val_loss: 0.3287
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0879 - val_accuracy: 0.9167 - val_loss: 0.2787
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0817 - val_accuracy: 0.9167 - val_loss: 0.3313
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0810 - val_accuracy: 0.9167 - val_loss: 0.3388
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9815 - loss: 0.0779 - val_accuracy: 0.9167 - val_loss: 0.2994
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0767 - val_accuracy: 0.9167 - val_loss: 0.3276
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0718 - val_accuracy: 0.9167 - val_loss: 0.3471
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9815 - loss: 0.0721 - val_accuracy: 0.9167 - val_loss: 0.3469
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0691 - val_accuracy: 0.9167 - val_loss: 0.3490
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0682 - val_accuracy: 0.9167 - val_loss: 0.3205
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0679 - val_accuracy: 0.9167 - val_loss: 0.3225
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0641 - val_accuracy: 0.9167 - val_loss: 0.3701
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9815 - loss: 0.0665 - val_accuracy: 0.9167 - val_loss: 0.3685
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0618 - val_accuracy: 0.9167 - val_loss: 0.3237
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0650 - val_accuracy: 0.9167 - val_loss: 0.3202
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0627 - val_accuracy: 0.9167 - val_loss: 0.3911
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9907 - loss: 0.0632 - val_accuracy: 0.9167 - val_loss: 0.3346
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0590 - val_accuracy: 0.9167 - val_loss: 0.3440
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Test Accuracy: 100.00%
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      1.00      1.00         9
#    virginica       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Predicted: versicolor
