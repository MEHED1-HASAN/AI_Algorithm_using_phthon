# %%
print("-"*90)
print("p\tq\t~p\tp^q\tpvq\tp-->q\tp<-->q")
print("-"*90)
values=[True,False]
for p in values:
    for q in values:
        print(f"{str(p)}\t{str(q)}\t{str(not p)}\t{str(p and q)}\t{str(p or q)}\t{str(q or (not p))}\t{str(p==q)}")
# Out:
# ------------------------------------------------------------------------------------------
# p	q	~p	p^q	pvq	p-->q	p<-->q
# ------------------------------------------------------------------------------------------
# True	True	False	True	True	True	True
# True	False	False	False	True	False	False
# False	True	True	False	True	True	False
# False	False	True	False	False	True	True

# %%
s1=input("Input fist statement:")
s2=input("Input second statement:")
p=input(f"Is ({s1}) TRUE or FALSE:")=="TRUE"
q=input(f"Is ({s2}) TRUE or FALSE:")=="TRUE"
op=input("Input operation name:")
result= None
statement=""

if op=="conjunction":
    result= p and q
    statement=f"{s1}^{s2}"
elif op=="disjunction":
    result= p or q
    statement=f"{s1}v{s2}"
elif op=="implication":
    result= (not p) or q
    statement=f"{s1}-->{s2}"
elif if op=="biconditional":
    result= p==q
    statement=f"{s1}<-->{s2}"
else:
    print("Invalid input")
# Out:
#   Cell In[4], line 18
#     elif if op=="biconditional":
#          ^
# SyntaxError: invalid syntax
